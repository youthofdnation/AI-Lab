# %%
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /home/ubuntu/.local/lib/python3.10/site-packages (1.66.3)
# Requirement already satisfied: sniffio in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (0.9.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (2.10.6)
# Requirement already satisfied: tqdm>4 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.23.0->openai) (2020.6.20)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)

# %%
import os

os.environ["OPENAI_DEFAULT_MODEL"] = "gpt-4o-mini"

# %%
import requests
import os

searching = '판교동 레스토랑'
kakao_api_key = os.getenv("KAKAO_API_KEY")
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": f"KakaoAK {kakao_api_key}"
}
places = requests.get(url, headers = headers).json()
places
# Out:
# {'documents': [{'address_name': '경기 성남시 분당구 판교동 614',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '21484277',
#    'phone': '031-8016-1865',
#    'place_name': '뚜에이오',
#    'place_url': 'http://place.map.kakao.com/21484277',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 24-2',
#    'x': '127.08878251993',
#    'y': '37.3913068226745'},
#   {'address_name': '경기 성남시 분당구 판교동 614-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '14589499',
#    'phone': '',
#    'place_name': '라비떼',
#    'place_url': 'http://place.map.kakao.com/14589499',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 16',
#    'x': '127.08955522531403',
#    'y': '37.39155131811151'},
#   {'address_name': '경기 성남시 분당구 판교동 599',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '16065056',
#    'phone': '031-8016-6262',
#    'place_name': '샤슬릭',
#    'place_url': 'http://place.map.kakao.com/16065056',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 45',
#    'x': '127.09300276802902',
#    'y': '37.38964029121598'},
#   {'address_name': '경기 성남시 분당구 판교동 600-5',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '708092398',
#    'phone': '010-3005-9541',
#    'place_name': '오스테리아 워모잡',
#    'place_url': 'http://place.map.kakao.com/708092398',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 40-1',
#    'x': '127.093826013936',
#    'y': '37.3896666715851'},
#   {'address_name': '경기 성남시 분당구 판교동 617-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '27300858',
#    'phone': '0502-5551-6969',
#    'place_name': '라스토리아1001',
#    'place_url': 'http://place.map.kakao.com/27300858',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 24',
#    'x': '127.088863533106',
#    'y': '37.3910580796215'},
#   {'address_name': '경기 성남시 분당구 판교동 610',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '2092406855',
#    'phone': '031-701-0345',
#    'place_name': '피제리아 비니스',
#    'place_url': 'http://place.map.kakao.com/2092406855',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 70',
#    'x': '127.091160140249',
#    'y': '37.3908085502984'},
#   {'address_name': '경기 성남시 분당구 판교동 618-7',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 멕시칸,브라질',
#    'distance': '',
#    'id': '442176392',
#    'phone': '031-703-0255',
#    'place_name': '갓잇 서판교점',
#    'place_url': 'http://place.map.kakao.com/442176392',
#    'road_address_name': '경기 성남시 분당구 판교공원로5길 24',
#    'x': '127.089829598053',
#    'y': '37.3905725995806'},
#   {'address_name': '경기 성남시 분당구 판교동 616-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자',
#    'distance': '',
#    'id': '1363058678',
#    'phone': '031-709-7499',
#    'place_name': '피제리아 살레르노 서판교점',
#    'place_url': 'http://place.map.kakao.com/1363058678',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 35',
#    'x': '127.09016326928636',
#    'y': '37.39102555996761'},
#   {'address_name': '경기 성남시 분당구 판교동 497',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 도미노피자',
#    'distance': '',
#    'id': '18154958',
#    'phone': '031-8017-9096',
#    'place_name': '도미노피자 판교점',
#    'place_url': 'http://place.map.kakao.com/18154958',
#    'road_address_name': '경기 성남시 분당구 서판교로 160',
#    'x': '127.09485899977564',
#    'y': '37.400209605227566'},
#   {'address_name': '경기 성남시 분당구 판교동 567-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1813415551',
#    'phone': '031-8016-0168',
#    'place_name': '플랩잭팬트리 본점',
#    'place_url': 'http://place.map.kakao.com/1813415551',
#    'road_address_name': '경기 성남시 분당구 서판교로44번길 17-11',
#    'x': '127.099584320006',
#    'y': '37.3916234885259'},
#   {'address_name': '경기 성남시 분당구 판교동 602-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '1793834083',
#    'phone': '031-781-0122',
#    'place_name': '에이치이에이',
#    'place_url': 'http://place.map.kakao.com/1793834083',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 67',
#    'x': '127.091385646215',
#    'y': '37.3905245541454'},
#   {'address_name': '경기 성남시 분당구 판교동 512',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 파파존스',
#    'distance': '',
#    'id': '27334535',
#    'phone': '031-709-9492',
#    'place_name': '파파존스 판교점',
#    'place_url': 'http://place.map.kakao.com/27334535',
#    'road_address_name': '경기 성남시 분당구 서판교로 154',
#    'x': '127.09521543438433',
#    'y': '37.39985071235571'},
#   {'address_name': '경기 성남시 분당구 판교동 602-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '817384546',
#    'phone': '031-778-6463',
#    'place_name': '칠리로29 판교점',
#    'place_url': 'http://place.map.kakao.com/817384546',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 69',
#    'x': '127.09122079999591',
#    'y': '37.39054450391926'},
#   {'address_name': '경기 성남시 분당구 판교동 614-9',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1992463433',
#    'phone': '',
#    'place_name': '일로이 키친',
#    'place_url': 'http://place.map.kakao.com/1992463433',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 10',
#    'x': '127.09016037466169',
#    'y': '37.3914373294357'},
#   {'address_name': '경기 성남시 분당구 판교동 612-3',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 반올림피자',
#    'distance': '',
#    'id': '1900750945',
#    'phone': '031-704-7773',
#    'place_name': '반올림피자 경기성남판교점',
#    'place_url': 'http://place.map.kakao.com/1900750945',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 3',
#    'x': '127.090792031107',
#    'y': '37.3908313590605'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '레스토랑',
#    'region': [],
#    'selected_region': '경기 성남시 분당구 판교동'},
#   'total_count': 262}}

# %%
question = "판교동에 있는 레스토랑을 두세개 추천해줘."

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": """다음 질문에서 지명 하나와 가장 중요한 키워드 하나를 추출해서 하나로 붙여줘.
원하는 형식:
<place>:<keyword>
"""
    },
    {
      "role": "user",
      "content": question
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 판교동:레스토랑

# %%
array = response.choices[0].message.content.split(":")
location = array[0]
keyword = array[1]

location, keyword
# Out:
# ('판교동', '레스토랑')

# %%
import requests

searching = f'{location} {keyword}'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
headers = {
    "Authorization": f"KakaoAK {kakao_api_key}"
}
places = requests.get(url, headers = headers).json()
places
# Out:
# {'documents': [{'address_name': '경기 성남시 분당구 판교동 614',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '21484277',
#    'phone': '031-8016-1865',
#    'place_name': '뚜에이오',
#    'place_url': 'http://place.map.kakao.com/21484277',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 24-2',
#    'x': '127.08878251993',
#    'y': '37.3913068226745'},
#   {'address_name': '경기 성남시 분당구 판교동 614-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '14589499',
#    'phone': '',
#    'place_name': '라비떼',
#    'place_url': 'http://place.map.kakao.com/14589499',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 16',
#    'x': '127.08955522531403',
#    'y': '37.39155131811151'},
#   {'address_name': '경기 성남시 분당구 판교동 599',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '16065056',
#    'phone': '031-8016-6262',
#    'place_name': '샤슬릭',
#    'place_url': 'http://place.map.kakao.com/16065056',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 45',
#    'x': '127.09300276802902',
#    'y': '37.38964029121598'},
#   {'address_name': '경기 성남시 분당구 판교동 600-5',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '708092398',
#    'phone': '010-3005-9541',
#    'place_name': '오스테리아 워모잡',
#    'place_url': 'http://place.map.kakao.com/708092398',
#    'road_address_name': '경기 성남시 분당구 판교공원로2길 40-1',
#    'x': '127.093826013936',
#    'y': '37.3896666715851'},
#   {'address_name': '경기 성남시 분당구 판교동 617-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '27300858',
#    'phone': '0502-5551-6969',
#    'place_name': '라스토리아1001',
#    'place_url': 'http://place.map.kakao.com/27300858',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 24',
#    'x': '127.088863533106',
#    'y': '37.3910580796215'},
#   {'address_name': '경기 성남시 분당구 판교동 610',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '2092406855',
#    'phone': '031-701-0345',
#    'place_name': '피제리아 비니스',
#    'place_url': 'http://place.map.kakao.com/2092406855',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 70',
#    'x': '127.091160140249',
#    'y': '37.3908085502984'},
#   {'address_name': '경기 성남시 분당구 판교동 618-7',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 멕시칸,브라질',
#    'distance': '',
#    'id': '442176392',
#    'phone': '031-703-0255',
#    'place_name': '갓잇 서판교점',
#    'place_url': 'http://place.map.kakao.com/442176392',
#    'road_address_name': '경기 성남시 분당구 판교공원로5길 24',
#    'x': '127.089829598053',
#    'y': '37.3905725995806'},
#   {'address_name': '경기 성남시 분당구 판교동 616-6',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자',
#    'distance': '',
#    'id': '1363058678',
#    'phone': '031-709-7499',
#    'place_name': '피제리아 살레르노 서판교점',
#    'place_url': 'http://place.map.kakao.com/1363058678',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 35',
#    'x': '127.09016326928636',
#    'y': '37.39102555996761'},
#   {'address_name': '경기 성남시 분당구 판교동 497',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 도미노피자',
#    'distance': '',
#    'id': '18154958',
#    'phone': '031-8017-9096',
#    'place_name': '도미노피자 판교점',
#    'place_url': 'http://place.map.kakao.com/18154958',
#    'road_address_name': '경기 성남시 분당구 서판교로 160',
#    'x': '127.09485899977564',
#    'y': '37.400209605227566'},
#   {'address_name': '경기 성남시 분당구 판교동 567-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1813415551',
#    'phone': '031-8016-0168',
#    'place_name': '플랩잭팬트리 본점',
#    'place_url': 'http://place.map.kakao.com/1813415551',
#    'road_address_name': '경기 성남시 분당구 서판교로44번길 17-11',
#    'x': '127.099584320006',
#    'y': '37.3916234885259'},
#   {'address_name': '경기 성남시 분당구 판교동 602-2',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 이탈리안',
#    'distance': '',
#    'id': '1793834083',
#    'phone': '031-781-0122',
#    'place_name': '에이치이에이',
#    'place_url': 'http://place.map.kakao.com/1793834083',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 67',
#    'x': '127.091385646215',
#    'y': '37.3905245541454'},
#   {'address_name': '경기 성남시 분당구 판교동 512',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 파파존스',
#    'distance': '',
#    'id': '27334535',
#    'phone': '031-709-9492',
#    'place_name': '파파존스 판교점',
#    'place_url': 'http://place.map.kakao.com/27334535',
#    'road_address_name': '경기 성남시 분당구 서판교로 154',
#    'x': '127.09521543438433',
#    'y': '37.39985071235571'},
#   {'address_name': '경기 성남시 분당구 판교동 602-1',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '817384546',
#    'phone': '031-778-6463',
#    'place_name': '칠리로29 판교점',
#    'place_url': 'http://place.map.kakao.com/817384546',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 69',
#    'x': '127.09122079999591',
#    'y': '37.39054450391926'},
#   {'address_name': '경기 성남시 분당구 판교동 614-9',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식',
#    'distance': '',
#    'id': '1992463433',
#    'phone': '',
#    'place_name': '일로이 키친',
#    'place_url': 'http://place.map.kakao.com/1992463433',
#    'road_address_name': '경기 성남시 분당구 판교공원로3길 10',
#    'x': '127.09016037466169',
#    'y': '37.3914373294357'},
#   {'address_name': '경기 성남시 분당구 판교동 612-3',
#    'category_group_code': 'FD6',
#    'category_group_name': '음식점',
#    'category_name': '음식점 > 양식 > 피자 > 반올림피자',
#    'distance': '',
#    'id': '1900750945',
#    'phone': '031-704-7773',
#    'place_name': '반올림피자 경기성남판교점',
#    'place_url': 'http://place.map.kakao.com/1900750945',
#    'road_address_name': '경기 성남시 분당구 판교공원로1길 3',
#    'x': '127.090792031107',
#    'y': '37.3908313590605'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '레스토랑',
#    'region': [],
#    'selected_region': '경기 성남시 분당구 판교동'},
#   'total_count': 262}}

# %%
import json

context = ''
i = 1;
for place in places['documents']:
    context = context + f"{i}) {place['place_name']}, {place['address_name']}, {place['category_name']}"
    i = i + 1
context
# Out:
# '1) 뚜에이오, 경기 성남시 분당구 판교동 614, 음식점 > 양식 > 이탈리안2) 라비떼, 경기 성남시 분당구 판교동 614-6, 음식점 > 양식 > 이탈리안3) 샤슬릭, 경기 성남시 분당구 판교동 599, 음식점 > 양식4) 오스테리아 워모잡, 경기 성남시 분당구 판교동 600-5, 음식점 > 양식 > 이탈리안5) 라스토리아1001, 경기 성남시 분당구 판교동 617-1, 음식점 > 양식 > 이탈리안6) 피제리아 비니스, 경기 성남시 분당구 판교동 610, 음식점 > 양식 > 이탈리안7) 갓잇 서판교점, 경기 성남시 분당구 판교동 618-7, 음식점 > 양식 > 멕시칸,브라질8) 피제리아 살레르노 서판교점, 경기 성남시 분당구 판교동 616-6, 음식점 > 양식 > 피자9) 도미노피자 판교점, 경기 성남시 분당구 판교동 497, 음식점 > 양식 > 피자 > 도미노피자10) 플랩잭팬트리 본점, 경기 성남시 분당구 판교동 567-2, 음식점 > 양식11) 에이치이에이, 경기 성남시 분당구 판교동 602-2, 음식점 > 양식 > 이탈리안12) 파파존스 판교점, 경기 성남시 분당구 판교동 512, 음식점 > 양식 > 피자 > 파파존스13) 칠리로29 판교점, 경기 성남시 분당구 판교동 602-1, 음식점 > 양식14) 일로이 키친, 경기 성남시 분당구 판교동 614-9, 음식점 > 양식15) 반올림피자 경기성남판교점, 경기 성남시 분당구 판교동 612-3, 음식점 > 양식 > 피자 > 반올림피자'

# %%
import os
import openai
import json

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.chat.completions.create(
  model=os.getenv("OPENAI_DEFAULT_MODEL"),
  messages=[
    {
      "role": "system",
      "content": f"주어진 문단을 보고 다음 질문에 답해줘: {question}"
    },
    {
      "role": "user",
      "content": context
    }
  ],
  temperature=0,
  max_tokens=1024,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

print(response.choices[0].message.content)
# Out:
# 판교동에 있는 레스토랑 중 추천할 만한 두세 곳은 다음과 같습니다:
#
# 1. **뚜에이오** - 이탈리안 음식점으로, 맛있는 파스타와 피자를 제공합니다.
# 2. **라비떼** - 또 다른 이탈리안 레스토랑으로, 다양한 이탈리안 요리를 즐길 수 있습니다.
# 3. **오스테리아 워모잡** - 이탈리안 요리를 전문으로 하는 레스토랑으로, 분위기도 좋고 맛있는 음식을 제공합니다.
#
# 이 외에도 다양한 이탈리안 레스토랑이 있으니, 취향에 맞게 선택해 보세요!
